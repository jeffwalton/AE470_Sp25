# %% [markdown]
# # AE 470 Equations

# %% [markdown]
# ## Constants
#
# | parameter | value |
# | --- | --- |
# | $ r_{Earth} $ | $ 6378137 \; \mathrm{m} $ |
# | $ \mu_{Earth} = \mu_{\oplus} $ | $ 3.986 \times 10^{14} \; \mathrm{m}^3 / \mathrm{s}^2 = 3.986 \times 10^{5} \; \mathrm{km}^3 / \mathrm{s}^2 $ |
# | $ \mu_{Sun} = \mu_{\odot} $ | $1.327 \times 10^{20}  \; \mathrm{m}^3 / \mathrm{s}^2  $ |

# %% [markdown]
# ## Definition of Variables
#
# | variable | definition | usage |
# | --- | --- | --- |
# | a | orbit semi-major axis | Keplerian orbits |
# | $ \mathcal{E} $ | orbital specific mechanical energy |  |
# | $ \vec{\mathbf{h}} $ | specific angular momentum vector |  |
# | $ h =\; \mid\vec{\mathbf{h}}\mid $ | specific angular momentum |  |
# | $ \vec{\mathbf{e}} $ | eccentricity vector |  |
# | $ E $ | eccentric anomaly | Keplerian orbits |
# | $ e $ | eccentricity | Keplerian orbits |
# | $ M $ | mean anomaly | Keplerian orbits |
# | $ n $ | mean motion | Keplerian orbits |
# | $ p $ | semi-latus rectum or parameter | Keplerian orbits |
# | $ \vec{\mathbf{r}} $ | position vector |  |
# | $ r =\; \mid\vec{\mathbf{r}}\mid $ | magnitude of position vector |  |
# | $ T $ | orbital period |  |
# | $ t $ | time |  |
# | $ \vec{\mathbf{v}} \equiv \dot{ \vec{\mathbf{r}} }$ | velocity vector |  |
# | $ v = \; \mid\vec{\mathbf{v}}\mid$ |  magnitude of velocity vector |  |
# | $ \theta $ | true anolamy | Keplerian orbits |
# | $ \mu $ | gravitation parameter | Keplerian orbits |

# %% [markdown]
# ## Keplerian (Two-Body) Orbits
#
# \begin{equation}
# \boxed{ \boxed{ \ddot{\vec{\mathbf{r}}} = - \frac{\mu}{|\vec{\mathbf{r}}|^3} \vec{\mathbf{r}} } }
# \end{equation}
#
# \begin{equation}
# \boxed{ \vec{\mathbf{h}} \triangleq \vec{\mathbf{r}} \times \vec{\mathbf{v}} }
# \end{equation}
#
# \begin{equation}
# \boxed{ \mathcal{E} \triangleq \frac{v^2}{2} - \frac{\mu}{r} = \frac{\vec{\mathbf{v}} \cdot \vec{\mathbf{v}}}{2} - \frac{\mu}{r}
#  }
# \end{equation}
#
# \begin{equation}
# \boxed{ \vec{\mathbf{e}} \triangleq \frac{ \dot{\vec{\mathbf{r}}} \times \vec{\mathbf{h}} }{\mu} - \frac{ \vec{\mathbf{r}}}{r} }
# \end{equation}
#
# \begin{equation}
#  \boxed{r  = \frac{p}{1 + e \cos{\theta}}}
# \end{equation}
#
# \begin{equation}
# \boxed{ p = \frac{h^2}{\mu} }
# \end{equation}
#
# \begin{equation}
# a = \bigg( \frac{2}{r} - \frac{ v^2 }{\mu} \bigg)^{-1}
# \end{equation}
#
# \begin{equation}
# \boxed{ a = \frac{p}{1-e^2} }
# \end{equation}
#
# \begin{equation}
# \boxed{ a = \frac{h^2}{\mu}\frac{1}{1-e^2} }
# \end{equation}
#
# \begin{equation}
# \boxed{ \mathcal{E} = -\frac{\mu}{2 a} }
# \end{equation}
#
# \begin{equation}
# \boxed{ \mathcal{E} = \frac{\mu^2 (e^2 - 1)}{2 h^2} }
# \end{equation}
#
# \begin{equation}
# \boxed{ \mathcal{E} = \frac{\mu^2 (e^2 - 1)}{2 h^2} }
# \end{equation}
#
# \begin{equation}
# \boxed{ e = \sqrt{ 1+ \frac{2 \mathcal{E} h^2}{\mu^2} } }
# \end{equation}
#
# \begin{equation}
# \boxed{ v = \sqrt{ \mu \bigg( \frac{2}{r} - \frac{1}{a} \bigg) } }
# \end{equation}

# %% [markdown]
# ### Circular Orbits
#
# \begin{equation}
# \boxed{ v_{circular} = \sqrt{ \frac{\mu}{r} } }
# \end{equation}
#
# \begin{equation}
# \boxed{ T_{circular} = \frac{2 \pi }{\sqrt{ \mu} }r^{\frac{3}{2}} }
# \end{equation}
#
# \begin{equation}
# \boxed{ \mathcal{E}_{circular} = -\frac{\mu}{2 r} }
# \end{equation}
#
# \begin{equation}
# \boxed{ h = \sqrt{ \mu  r } }
# \end{equation}
#
# \begin{equation}
# n = \sqrt{ \frac{\mu}{r^3} }
# \end{equation}
#
# \begin{equation}
# \theta(t) - \theta(t_0) = n(t - t_0)
# \end{equation}

# %% [markdown]
# ### Elliptical Orbits
#
# \begin{equation}
# \boxed{ r_p + r_a = 2 a }
# \end{equation}
#
# \begin{equation}
# \boxed{ e = \frac{r_a - r_p}{r_a + r_p} }
# \end{equation}
#
# \begin{equation}
# \boxed{ T^2 = \frac{ 4 \pi^2 }{\mu}a^3 }
# \end{equation}
#
# \begin{equation}
# \boxed{ T^2 \propto a^3 }
# \end{equation}
#
# \begin{equation}
# \boxed{ T_{elliptical} = 2 \pi \sqrt{ \frac{a^3}{\mu} }}
# \end{equation}

# %% [markdown]
# #### Time of Flight (eliptical orbits)
#
# \begin{equation}
# \boxed{ \tan{\frac{\theta}{2}} = sqrt{ \frac{1+e}{1-e} } \tan{\frac{E}{2}} }
# \end{equation}
#
# \begin{equation}
# \boxed{ M = n(t - t_0) }
# \end{equation}
#
# Kepler's Equation
# \begin{equation}
# \boxed{  M = E - e \sin{ E }  }
# \end{equation}

# %% [markdown]
# \begin{equation}
# \boxed{  }
# \end{equation}
#
# \begin{equation}
# \boxed{  }
# \end{equation}
#
# \begin{equation}
# \boxed{  }
# \end{equation}

# %% [markdown]
# \begin{equation}
# \boxed{  }
# \end{equation}
#
# \begin{equation}
# \boxed{  }
# \end{equation}
#
# \begin{equation}
# \boxed{  }
# \end{equation}
#
# \begin{equation}
# \boxed{  }
# \end{equation}
#
# \begin{equation}
# \boxed{  }
# \end{equation}
#
# \begin{equation}
# \boxed{  }
# \end{equation}
